# %% [markdown]
# ### Salary vs Experience ( Linear Regression )

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# #### Load Dataset

# %%
emp = pd.read_csv('salary_data.csv')

# %%
emp.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
## This dataset has no null values and no duplicate values.

# %%
emp.shape
# Out:
# (30, 2)

# %%
emp.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %% [markdown]
# #### Data Visualization

# %%
sns.scatterplot(x='YearsExperience', y= 'Salary', data=emp)
plt.show()

# %%
x = emp[['YearsExperience']].values # Feature cols

# %%
y = emp['Salary'].values  # Target

# %% [markdown]
# ## Train Test Split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.5, random_state=10)

# %% [markdown]
# #### Model Create

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %% [markdown]
# ### Evaluation matrics

# %%
mse = mean_squared_error(y_test, y_pred)

# %%
mse
# Out:
# 34270993.83366794

# %%
mae = mean_absolute_error(y_test, y_pred)
mae
# Out:
# 4976.823445932439

# %%
r2 = r2_score(y_test, y_pred)
r2
# Out:
# 0.9277558201036822

# %%
print('Mean Squared Error: ', mse)
print('Mean Absolute Error: ', mae)
print('Mean r2 Score Error: ', r2)
# Out:
# Mean Squared Error:  34270993.83366794
# Mean Absolute Error:  4976.823445932439
# Mean r2 Score Error:  0.9277558201036822

# %% [markdown]
# ### Graph Visualization

# %%
plt.figure(figsize=(8,6))
plt.scatter(x,y, color='b',label='Data Points')
plt.plot(x, model.predict(x), color='red', linewidth=3, label='Best Fit Line')
plt.xlabel('Year of Exprience')
plt.ylabel('Salary')
plt.legend()
plt.show()

# %% [markdown]
# ## New Dataset

# %%
# How the new dataset is working
new_exp = np.array([[6.2]])
pred_salary = model.predict(new_exp)

# %%
print(pred_salary)
# Out:
# [84518.31596042]
